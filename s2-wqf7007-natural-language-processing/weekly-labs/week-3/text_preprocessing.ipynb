# %% [markdown]
# <h1 style="text-align: center;">Text Preprocessing 1 - Tutorial</h1>

# %% [markdown]
# Text Pre-processing common steps:
#
# 1. Text Cleaning: special characters, HTML tags, new lines
# 2. Tokenization: split text into sentences and words.
# 3. Stop Words Removal: remove words of little value like "the", "and", "a", "an".
# 4. Stemming: stripping the affixes from words.
# 5. Lemmatization: converting words to their base form.

# %% [markdown]
# ## Install Dependencies

# %%
# !pip3 install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.3.32-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from nltk) (4.67.1)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.7 MB/s  0:00:00
# Downloading regex-2026.3.32-cp311-cp311-macosx_11_0_arm64.whl (289 kB)
# Installing collected packages: regex, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nltk]1/2 [nltk]
# Successfully installed nltk-3.9.4 regex-2026.3.32

# %%
example_sentence = """A fair number of brave souls who upgraded their SI clock oscillator have
shared their experiences for this poll. Please send a brief message detailing
your experiences with the procedure. <br> Top speed attained, CPU rated speed,
add on cards & adapters, heat sinks, hour of usage per day, floppy disk
functionality with 800 and 1.4m floppies are especially requested."""

# %% [markdown]
# ## Cleaning

# %%
import re 

def clean_text(text):
    text = re.sub(r"<.*?>", " ", text)  # Remove HTML tags
    text = re.sub(r"\\n", " ", text)  # Remove explicit new-line characters
    text = re.sub(r"[^\w\s.]", " ", text)  # Remove special characters except for decimal points
    text = re.sub(r"\s+", " ", text)  # Replace multiple spaces with a single space
    return text.strip().lower()

# %%
cleaned_text = clean_text(example_sentence)
print(cleaned_text)
# Out:
# a fair number of brave souls who upgraded their si clock oscillator have shared their experiences for this poll. please send a brief message detailing your experiences with the procedure. top speed attained cpu rated speed add on cards adapters heat sinks hour of usage per day floppy disk functionality with 800 and 1.4m floppies are especially requested.

# %% [markdown]
# ## Tokenization

# %%
import nltk
nltk.download('punkt_tab') #model for sentence tokenizer
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/fabienyah/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
#Sentence Tokenizer
from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(cleaned_text)
print('number of sentences: ', len(tokenized_sent))
print(tokenized_sent)
# Out:
# number of sentences:  3
# ['a fair number of brave souls who upgraded their si clock oscillator have shared their experiences for this poll.', 'please send a brief message detailing your experiences with the procedure.', 'top speed attained cpu rated speed add on cards adapters heat sinks hour of usage per day floppy disk functionality with 800 and 1.4m floppies are especially requested.']

# %%
#Word Tokenizer
from nltk.tokenize import word_tokenize
tokenized = word_tokenize(cleaned_text)
print(tokenized)
# Out:
# ['a', 'fair', 'number', 'of', 'brave', 'souls', 'who', 'upgraded', 'their', 'si', 'clock', 'oscillator', 'have', 'shared', 'their', 'experiences', 'for', 'this', 'poll', '.', 'please', 'send', 'a', 'brief', 'message', 'detailing', 'your', 'experiences', 'with', 'the', 'procedure', '.', 'top', 'speed', 'attained', 'cpu', 'rated', 'speed', 'add', 'on', 'cards', 'adapters', 'heat', 'sinks', 'hour', 'of', 'usage', 'per', 'day', 'floppy', 'disk', 'functionality', 'with', '800', 'and', '1.4m', 'floppies', 'are', 'especially', 'requested', '.']

# %%
#Tweet Tokenizer compared to word_tokenize
from nltk.tokenize import TweetTokenizer
tweet = "Dont take cryptocurrency advice from people on Twitter 😃👍 #crypto"
tokenizer = TweetTokenizer()
tokenized_tweet = tokenizer.tokenize(tweet)
print(tokenized_tweet)
print(word_tokenize(tweet))
# Out:
# ['Dont', 'take', 'cryptocurrency', 'advice', 'from', 'people', 'on', 'Twitter', '😃', '👍', '#crypto']
# ['Dont', 'take', 'cryptocurrency', 'advice', 'from', 'people', 'on', 'Twitter', '😃👍', '#', 'crypto']

# %% [markdown]
# ## Stemming and Lemmatization

# %% [markdown]
# ### 1- NLTK

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

# %% [markdown]
# Remember That:
# * Porter Stemmer removes suffixes in a rule-based manner
# * It does not always return valid English words
# * Some words retain meaningful roots

# %%
# Standard cases
print(porter.stem('argue'))
print(porter.stem('argued'))
print(porter.stem('argues'))
print(porter.stem('arguing'))
# Out:
# argu
# argu
# argu
# argu

# %%
# Plurals and derivational forms
print(porter.stem('running'))    
print(porter.stem('runner'))     
print(porter.stem('flies'))      
print(porter.stem('fly'))
print(porter.stem('crying'))
# Out:
# run
# runner
# fli
# fli
# cri

# %%
# Complex endings
print(porter.stem('happiness'))  
print(porter.stem('university'))
print(porter.stem('national'))
print(porter.stem('generalization'))
# Out:
# happi
# univers
# nation
# gener

# %% [markdown]
# ## When to Use PorterStemmer?
# * For lightweight and rule-based stemming such as text classification and IR systems.
# * For more linguistically accurate results, consider lemmatization instead (e.g., WordNetLemmatizer).

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/fabienyah/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("argue", 'v'))
print(lemmatizer.lemmatize("argued", 'v')) 
print(lemmatizer.lemmatize("argues", 'v'))
print(lemmatizer.lemmatize("arguing", 'n'))
# Out:
# argue
# argue
# argue
# arguing

# %%
print(lemmatizer.lemmatize("better", 'a'))
print(lemmatizer.lemmatize("running", 'v'))
print(lemmatizer.lemmatize("running", 'n'))
print(lemmatizer.lemmatize("flies", 'n'))
print(lemmatizer.lemmatize("flies", 'v'))
print(lemmatizer.lemmatize("mice", 'n'))
# Out:
# good
# run
# running
# fly
# fly
# mouse

# %%
#WordNetLemmatizer requires the correct POS tag to be accurate, default is noun
print(lemmatizer.lemmatize("went"))

## When POS tag is provided
print("POS Tag provided:")
print(lemmatizer.lemmatize("went", "v"))
# Out:
# went
# POS Tag provided:
# go

# %% [markdown]
# ### 2- spaCy

# %%
# !pip3 install spacy
# !python3 -m spacy download en_core_web_md
# Out:
# Collecting spacy
#   Downloading spacy-3.8.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.11.12)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Requirement already satisfied: click>=8.2.1 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open>=5.2.1 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.5.0)
# Requirement already satisfied: httpx>=0.24.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: wrapt in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/fabienyah/miniconda3/envs/thispy11/lib/python3.11/site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.13-cp311-cp311-macosx_11_0_arm64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 53.2 MB/s  0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl (43 kB)
# Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl (27 kB)
# Downloading preshed-3.0.13-cp311-cp311-macosx_11_0_arm64.whl (137 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp311-cp311-macosx_11_0_arm64.whl (657 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.5/657.5 kB 47.7 MB/s  0:00:00
# Downloading thinc-8.3.13-cp311-cp311-macosx_11_0_arm64.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.1/812.1 kB 42.5 MB/s  0:00:00
# Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.4 MB/s  0:00:00
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, shellingham, murmurhash, mdurl, cymem, confection, cloudpathlib, catalogue, blis, srsly, preshed, markdown-it-py, thinc, rich, typer, weasel, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [spacy]m18/19 [spacy]
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-1.3.3 cymem-2.0.13 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.15 preshed-3.0.13 rich-14.3.3 shellingham-1.5.4 spacy-3.8.13 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 typer-0.24.1 wasabi-1.1.3 weasel-1.0.0
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 41.6 MB/s  0:00:00m0:00:0100:01
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import spacy
nlp = spacy.load('en_core_web_md') #load the core English language model

# %% [raw]
# SpaCy has Built-in POS tagging (no need to separately tag words like in NLTK).

# %%
doc=nlp('After the cats fell asleep, the mice went out to play.')
for token in doc:
    print(token,'-->',token.lemma_)
# Out:
# After --> after
# the --> the
# cats --> cat
# fell --> fall
# asleep --> asleep
# , --> ,
# the --> the
# mice --> mouse
# went --> go
# out --> out
# to --> to
# play --> play
# . --> .

# %%
#lemmatize our original example sentence
doc = nlp(cleaned_text)

# Extract original words and their lemmatized forms
original = [token.text for token in doc]
lemmatized = [token.lemma_.lower() for token in doc]

# Display results in aligned format
print(f"{'Original':<15} {'Lemmatized':<15}")
print("=" * 30)
for orig, lem in zip(original, lemmatized):
    print(f"{orig:<15} {lem:<15}")
# Out:
# Original        Lemmatized
# ==============================
# a               a
# fair            fair
# number          number
# of              of
# brave           brave
# souls           soul
# who             who
# upgraded        upgrade
# their           their
# si              si
# clock           clock
# oscillator      oscillator
# have            have
# shared          share
# their           their
# experiences     experience
# for             for
# this            this
# poll            poll
# .               .
# please          please
# send            send
# a               a
# brief           brief
# message         message
# detailing       detail
# your            your
# experiences     experience
# with            with
# the             the
# procedure       procedure
# .               .
# top             top
# speed           speed
# attained        attain
# cpu             cpu
# rated           rat
# speed           speed
# add             add
# on              on
# cards           card
# adapters        adapter
# heat            heat
# sinks           sink
# hour            hour
# of              of
# usage           usage
# per             per
# day             day
# floppy          floppy
# disk            disk
# functionality   functionality
# with            with
# 800             800
# and             and
# 1.4             1.4
# m               m
# floppies        floppy
# are             be
# especially      especially
# requested       request
# .               .

# %% [markdown]
# ## Stop Word Removal

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fabienyah/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# Get stop words list
stop = stopwords.words('english')

# Convert to a set to remove duplicates
unique_stopwords = set(stop)

# Convert back to a list
stop = list(unique_stopwords)

print("Total unique stop words:", len(stop))
print("Sample stop words:", stop[:100])  # Print the first 100 stop words
# Out:
# Total unique stop words: 198
# Sample stop words: ["haven't", 'hers', 'she', "they've", 'under', 'whom', 'ours', 'there', 'won', 'had', 'who', 'is', "they'll", 'll', "mustn't", 'has', 'which', 'doesn', 'our', "didn't", "it's", 'as', 'hadn', 'these', 'will', 'y', 'isn', 'his', "it'll", 'such', 'itself', 'or', 'haven', "needn't", 'when', 'they', 'again', 'wouldn', "we'll", 'do', 'to', 'them', 'the', 'this', 'needn', 'couldn', 'here', 'few', 'while', 'other', "he'd", "don't", 'myself', 'so', "we'd", 'was', "should've", "you've", 'am', 'more', 'you', 'he', 'once', 'but', 'a', 'yourself', 'off', 'd', "she's", 'ourselves', 'don', 'because', 'me', 'up', 'now', 'any', 'where', 'then', 'just', 'not', 'out', 'we', 've', 'doing', 'herself', "we've", 'each', 'her', 'most', "shan't", 'after', 'themselves', "it'd", 'what', 'only', "i'd", 'through', 're', 'some', 'o']

# %%
import spacy 
from spacy.lang.en.stop_words import STOP_WORDS
stop_words=list(STOP_WORDS)

print("Total unique stop words:", len(stop_words))
print("Sample stop words:", stop_words[:100])  # First 100 stop words
# Out:
# Total unique stop words: 326
# Sample stop words: ['fifteen', 'four', 'there', '’m', 'full', 'twelve', 'third', 'thereupon', 'could', 'as', 'these', 'will', 'get', 'his', 'forty', 'might', 'to', 'amongst', 'while', 'toward', 'am', 'you', 'something', 'enough', 'whether', 'off', 'see', 'anything', 'ourselves', 'via', 'wherein', 'yet', 'any', '‘re', 'thereafter', 'we', 'please', 'seeming', 'perhaps', 'anyone', 'meanwhile', 'often', 'least', 'beforehand', 're', 'someone', 'less', 'noone', 'everyone', 'five', 'became', 'anyway', "'d", 'can', 'further', 'make', 'except', 'my', '‘m', 'thru', 'being', 'due', 'together', 'above', 'against', 'hence', 'per', 'around', 'otherwise', 'him', 'too', 'move', 'must', 'whereafter', 'besides', 'should', 'about', 'with', 'down', 'same', 'regarding', 'their', 'even', '‘s', 'us', 'much', 'seem', 'never', 'though', 'into', 'under', 'ours', 'had', 'who', 'everywhere', 'is', 'last', 'which', "'re", 'several']

# %%
stop_words_removed = [word for word in lemmatized if word not in stop_words]
removed_arr = [word for word in lemmatized if word in stop_words]

# %%
print(stop_words_removed)
# Out:
# ['fair', 'number', 'brave', 'soul', 'upgrade', 'si', 'clock', 'oscillator', 'share', 'experience', 'poll', '.', 'send', 'brief', 'message', 'detail', 'experience', 'procedure', '.', 'speed', 'attain', 'cpu', 'rat', 'speed', 'add', 'card', 'adapter', 'heat', 'sink', 'hour', 'usage', 'day', 'floppy', 'disk', 'functionality', '800', '1.4', 'm', 'floppy', 'especially', 'request', '.']

# %%
print(removed_arr)
# Out:
# ['a', 'of', 'who', 'their', 'have', 'their', 'for', 'this', 'please', 'a', 'your', 'with', 'the', 'top', 'on', 'of', 'per', 'with', 'and', 'be']
